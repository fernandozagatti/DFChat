# %% [markdown]
# ### Using DFChat

# %%
import sys
sys.path.append('src')

import pandas as pd
from dfchat import DFChat

df = pd.read_csv('Datasets/Human Stress Prediction.csv')
chat_llm = DFChat(df)
response = chat_llm.chat("What are the main characteristics of the dataset?")
# Out:
# Important: Text generated by AI and may contain incorrect information, always check the content.
# ```python
# import pandas as pd
#
# # Display the first few rows of the DataFrame
# display('First few rows of the DataFrame:')
# display(df.head())
#
# # Check for missing values
# display('Missing values count:')
# display(df.isnull().sum())
#
# # Get the data types of the columns
# display('Data types of the columns:')
# display(df.dtypes)
#
# # Get summary statistics for numerical columns
# display('Summary statistics for numerical columns:')
# display(df[['label', 'confidence', 'social_timestamp']].describe())
#
# # Get information about categorical columns
# display('Information about categorical columns:')
# for column in ['subreddit', 'post_id', 'sentence_range', 'text']:
#     display(f'Column: {column}')
#     display(df[column].value_counts().head())
#
# # Get the shape of the DataFrame
# display('Shape of the DataFrame:')
# display(df.shape)
#
# ...

# %% [markdown]
# ### Config the label used

# %%
import sys
sys.path.append('src')

import pandas as pd
from dfchat import DFChat

df = pd.read_csv('Datasets/Human Stress Prediction.csv')
chat_llm = DFChat(df, target='label')
response = chat_llm.chat("What are the distribution of the label?")
# Out:
# Important: Text generated by AI and may contain incorrect information, always check the content.
# To analyze the distribution of the 'label' column, we can use the pandas library to compute summary statistics and visualize the distribution.
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
#
# # Compute summary statistics for the 'label' column
# display(df['label'].describe())
#
# # Plot a bar chart to visualize the distribution of 'label'
# df['label'].value_counts().plot(kind='bar')
# plt.title('Distribution of Label')
# plt.xlabel('Label')
# plt.ylabel('Count')
# plt.show()
# ```
# count    2838.000000
# mean        0.524313
# std         0.499497
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: label, dtype: float64
# ...

# %% [markdown]
# ### Config the used LLM

# %%
import sys
sys.path.append('src')

import pandas as pd
from dfchat import DFChat

df = pd.read_csv('Datasets/Human Stress Prediction.csv')
chat_llm = DFChat(df)
response = chat_llm.chat("What are the distribution of the label?", model="deepseek-r1-distill-llama-70b")
# Out:
# Important: Text generated by AI and may contain incorrect information, always check the content.
#
#
# To analyze the distribution of the 'label' column, we can use the `value_counts()` method to show the frequency of each label and calculate the proportions.
#
# ```python
# # Display the distribution of the label column
# print('Distribution of the label column:')
# display(df['label'].value_counts())
#
# # Calculate and display the proportions of each label
# print('\nProportions of each label:')
# display(df['label'].value_counts(normalize=True) * 100)
# ```
# Distribution of the label column:
# label
# 1    1488
# 0    1350
# Name: count, dtype: int64
# Proportions of each label:
# label
# 1    52.43129
# 0    47.56871
# Name: proportion, dtype: float64
# This will show both the count and percentage distribution of the labels in the dataset.
